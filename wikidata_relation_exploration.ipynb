# %% [markdown]
# # wikidata parsing
# 위키데이터에서 id를 이용해 entity와 relation을 구분하여 entities, relations 리스트에 저장한다.

# %%
import bz2
import json
import pandas as pd

def wikidata_parsing(filename):
    '''
    json.bz2 file parsing function
    '''
    with bz2.open(filename, mode='rt', encoding='utf-8') as f:
        for line in f:
            try:
                yield json.loads(line.rstrip(',\n'))
            except json.decoder.JSONDecodeError:
                continue
                
entities, relations = [], []

# number of files setting
num_of_files = 5

for num in range(num_of_files):
    filename = 'data/split-' + ('%04d' % num) + '.json.bz2'
    
    for i, data in enumerate(wikidata_parsing(filename)):
        if data['id'][0] == 'Q':
            entities.append(data)
        elif data['id'][0] == 'P' or data['id'][0] == 'p':
            relations.append(data)
        if i % 5000 == 4999:
            print(f'total entities: {len(entities)}, total relations: {len(relations)}')
# Out:
# total entities: 5000, total relations: 0
# total entities: 10000, total relations: 0
# total entities: 15000, total relations: 0
# total entities: 20000, total relations: 0
# total entities: 25000, total relations: 0
# total entities: 30000, total relations: 0
# total entities: 35000, total relations: 0
# total entities: 40000, total relations: 0
# total entities: 45000, total relations: 0
# total entities: 50000, total relations: 0
# total entities: 55000, total relations: 0
# total entities: 60000, total relations: 0
# total entities: 65000, total relations: 0
# total entities: 70000, total relations: 0
# total entities: 75000, total relations: 0
# total entities: 80000, total relations: 0
# total entities: 85000, total relations: 0
# total entities: 90000, total relations: 0
# total entities: 95000, total relations: 0
# total entities: 104999, total relations: 0
# total entities: 109999, total relations: 0
# total entities: 114999, total relations: 0
# total entities: 119999, total relations: 0
# total entities: 124999, total relations: 0
# total entities: 129999, total relations: 0
# total entities: 134999, total relations: 0
# total entities: 139999, total relations: 0
# total entities: 144999, total relations: 0
# total entities: 149999, total relations: 0
# total entities: 154999, total relations: 0
# total entities: 159999, total relations: 0
# total entities: 164999, total relations: 0
# total entities: 169999, total relations: 0
# total entities: 174999, total relations: 0
# total entities: 179999, total relations: 0
# total entities: 184999, total relations: 0
# total entities: 189999, total relations: 0
# total entities: 194999, total relations: 0
# total entities: 199999, total relations: 0
# total entities: 204999, total relations: 0
# total entities: 209999, total relations: 0
# total entities: 214999, total relations: 0
# total entities: 219999, total relations: 0
# total entities: 224999, total relations: 0
# total entities: 229999, total relations: 0
# total entities: 234999, total relations: 0
# total entities: 239999, total relations: 0
# total entities: 244999, total relations: 0
# total entities: 249999, total relations: 0
# total entities: 254999, total relations: 0
# total entities: 259999, total relations: 0
# total entities: 264999, total relations: 0
# total entities: 269999, total relations: 0
# total entities: 274999, total relations: 0
# total entities: 279999, total relations: 0
# total entities: 284999, total relations: 0
# total entities: 289999, total relations: 0
# total entities: 294999, total relations: 0
# total entities: 299999, total relations: 0
# total entities: 304999, total relations: 0
# total entities: 309999, total relations: 0
# total entities: 314999, total relations: 0
# total entities: 319999, total relations: 0
# total entities: 324999, total relations: 0
# total entities: 329999, total relations: 0
# total entities: 334999, total relations: 0
# total entities: 339999, total relations: 0
# total entities: 344999, total relations: 0
# total entities: 349999, total relations: 0
# total entities: 354999, total relations: 0
# total entities: 359999, total relations: 0
# total entities: 364999, total relations: 0
# total entities: 369999, total relations: 0
# total entities: 374999, total relations: 0
# total entities: 379999, total relations: 0
# total entities: 384999, total relations: 0
# total entities: 389999, total relations: 0
# total entities: 394999, total relations: 0
# total entities: 399999, total relations: 0
# total entities: 404999, total relations: 0
# total entities: 409999, total relations: 0
# total entities: 414999, total relations: 0
# total entities: 419999, total relations: 0
# total entities: 424999, total relations: 0
# total entities: 429999, total relations: 0
# total entities: 434999, total relations: 0
# total entities: 439999, total relations: 0
# total entities: 444999, total relations: 0
# total entities: 449999, total relations: 0
# total entities: 454999, total relations: 0
# total entities: 459999, total relations: 0
# total entities: 464999, total relations: 0
# total entities: 469995, total relations: 4
# total entities: 474995, total relations: 4
# total entities: 479995, total relations: 4
# total entities: 484994, total relations: 5
# total entities: 489994, total relations: 5
# total entities: 494994, total relations: 5
# total entities: 499994, total relations: 5

# %%
len(entities), len(relations)
# Out:
# (499994, 5)

# %% [markdown]
# # extract entity information
# parsing한 wikidata에서 필요한 정보만을 추출하여 딕셔너리 형태로 저장한다.
# <br/> 저장하는 정보는 entity의 'id','labels','descriptions','aliases','claims'로 5가지이다.
# <br/>영어와 한국어에 대해 따로 ent_info_list_en, ent_info_list_ko 리스트에 저장한다(한국어로 존재하지 않는 property가 있음).

# %%
from collections import defaultdict

def extract_entity_info(data, lang='en'):
    '''
    includes 5 properties of wikidata(id, labels, descriptions, aliases, claims)
    in dictionary type
    '''
    new = defaultdict(list)
    
    new['id'] = data['id']
    
    if lang in data['labels'].keys():
        new['labels'] = data['labels'][lang]['value']
        
    if lang in data['descriptions'].keys():
        new['descriptions'] = data['descriptions'][lang]['value']
        
    if lang in data['aliases'].keys():
        new['aliases'] = [x['value'] for x in data['aliases'][lang]]
    new['claims'] = list(data['claims'].keys())
    
    return new

# %%
ent_info_list_en, ent_info_list_ko = [], []

for entity in entities:
    ent_info_list_en.append(extract_entity_info(entity))
    ent_info_list_ko.append(extract_entity_info(entity, lang='ko'))

# %%
print(len(ent_info_list_en), len(ent_info_list_ko))
# Out:
# 499994 499994

# %%
ent_info_list_en[0]
# Out:
# defaultdict(list,
#             {'id': 'Q31',
#              'labels': 'Belgium',
#              'descriptions': 'country in western Europe',
#              'aliases': ['Kingdom of Belgium', 'BEL', 'be', '🇧🇪', 'BE'],
#              'claims': ['P2924',
#               'P1344',
#               'P1082',
#               'P1667',
#               'P1151',
#               'P3348',
#               'P1333',
#               'P1546',
#               'P5125',
#               'P349',
#               'P38',
#               'P3365',
#               'P3221',
#               'P2581',
#               'P1566',
#               'P227',
#               'P487',
#               'P1792',
#               'P2852',
#               'P3916',
#               'P2853',
#               'P395',
#               'P3238',
#               'P1335',
#               'P2633',
#               'P298',
#               'P1448',
#               'P1313',
#               'P3417',
#               'P3529',
#               'P417',
#               'P998',
#               'P17',
#               'P486',
#               'P2959',
#               'P3106',
#               'P122',
#               'P982',
#               'P1552',
#               'P94',
#               'P2981',
#               'P2573',
#               'P3422',
#               'P793',
#               'P530',
#               'P571',
#               'P1906',
#               'P935',
#               'P194',
#               'P214',
#               'P5180',
#               'P605',
#               'P2184',
#               'P4613',
#               'P3911',
#               'P37',
#               'P3984',
#               'P30',
#               'P36',
#               'P856',
#               'P237',
#               'P3271',
#               'P1549',
#               'P3896',
#               'P949',
#               'P402',
#               'P4725',
#               'P3068',
#               'P1332',
#               'P1334',
#               'P691',
#               'P906',
#               'P3241',
#               'P2258',
#               'P4841',
#               'P2979',
#               'P1225',
#               'P5198',
#               'P3270',
#               'P1315',
#               'P3001',
#               'P3000',
#               'P910',
#               'P3612',
#               'P35',
#               'P268',
#               'P1791',
#               'P242',
#               'P1617',
#               'P2997',
#               'P1036',
#               'P1081',
#               'P5008',
#               'P3743',
#               'P6',
#               'P984',
#               'P463',
#               'P2163',
#               'P4342',
#               'P1198',
#               'P5658',
#               'P4427',
#               'P5573',
#               'P1417',
#               'P4629',
#               'P1830',
#               'P948',
#               'P1740',
#               'P2884',
#               'P208',
#               'P2238',
#               'P1465',
#               'P2347',
#               'P85',
#               'P209',
#               'P2250',
#               'P1296',
#               'P361',
#               'P373',
#               'P78',
#               'P2046',
#               'P47',
#               'P6150',
#               'P31',
#               'P610',
#               'P1464',
#               'P2927',
#               'P4672',
#               'P1813',
#               'P1622',
#               'P2982',
#               'P1589',
#               'P3222',
#               'P898',
#               'P299',
#               'P421',
#               'P269',
#               'P5247',
#               'P150',
#               'P3024',
#               'P474',
#               'P646',
#               'P3175',
#               'P138',
#               'P244',
#               'P297',
#               'P1451',
#               'P163',
#               'P625',
#               'P901',
#               'P3509',
#               'P1343',
#               'P41',
#               'P5982',
#               'P5140',
#               'P92',
#               'P5019',
#               'P6104',
#               'P1842',
#               'P6573',
#               'P5250',
#               'P4801',
#               'P527',
#               'P1304',
#               'P2936',
#               'P6363',
#               'P6897',
#               'P5905',
#               'P3864',
#               'P6404',
#               'P1705',
#               'P7012',
#               'P6766',
#               'P5002',
#               'P6849',
#               'P989',
#               'P7471',
#               'P1245',
#               'P7314',
#               'P902',
#               'P3067',
#               'P2596',
#               'P5400',
#               'P7870',
#               'P7867',
#               'P2855',
#               'P7818',
#               'P7829',
#               'P7827',
#               'P7832',
#               'P7822',
#               'P443',
#               'P5437',
#               'P7982',
#               'P6058',
#               'P7859',
#               'P7322',
#               'P8349',
#               'P8402',
#               'P8408',
#               'P6385',
#               'P8406',
#               'P1365',
#               'P8519',
#               'P5063',
#               'P1438',
#               'P3749',
#               'P6200',
#               'P8714',
#               'P8744',
#               'P5587',
#               'P7157',
#               'P8826',
#               'P6839',
#               'P8309',
#               'P4527',
#               'P5456',
#               'P8974',
#               'P9037',
#               'P9100',
#               'P8814',
#               'P9123']})

# %%
ent_info_list_ko[0]
# Out:
# defaultdict(list,
#             {'id': 'Q31',
#              'labels': '벨기에',
#              'descriptions': '서유럽에 위치한 국가',
#              'aliases': ['벨기에 왕국', '벨기에왕국'],
#              'claims': ['P2924',
#               'P1344',
#               'P1082',
#               'P1667',
#               'P1151',
#               'P3348',
#               'P1333',
#               'P1546',
#               'P5125',
#               'P349',
#               'P38',
#               'P3365',
#               'P3221',
#               'P2581',
#               'P1566',
#               'P227',
#               'P487',
#               'P1792',
#               'P2852',
#               'P3916',
#               'P2853',
#               'P395',
#               'P3238',
#               'P1335',
#               'P2633',
#               'P298',
#               'P1448',
#               'P1313',
#               'P3417',
#               'P3529',
#               'P417',
#               'P998',
#               'P17',
#               'P486',
#               'P2959',
#               'P3106',
#               'P122',
#               'P982',
#               'P1552',
#               'P94',
#               'P2981',
#               'P2573',
#               'P3422',
#               'P793',
#               'P530',
#               'P571',
#               'P1906',
#               'P935',
#               'P194',
#               'P214',
#               'P5180',
#               'P605',
#               'P2184',
#               'P4613',
#               'P3911',
#               'P37',
#               'P3984',
#               'P30',
#               'P36',
#               'P856',
#               'P237',
#               'P3271',
#               'P1549',
#               'P3896',
#               'P949',
#               'P402',
#               'P4725',
#               'P3068',
#               'P1332',
#               'P1334',
#               'P691',
#               'P906',
#               'P3241',
#               'P2258',
#               'P4841',
#               'P2979',
#               'P1225',
#               'P5198',
#               'P3270',
#               'P1315',
#               'P3001',
#               'P3000',
#               'P910',
#               'P3612',
#               'P35',
#               'P268',
#               'P1791',
#               'P242',
#               'P1617',
#               'P2997',
#               'P1036',
#               'P1081',
#               'P5008',
#               'P3743',
#               'P6',
#               'P984',
#               'P463',
#               'P2163',
#               'P4342',
#               'P1198',
#               'P5658',
#               'P4427',
#               'P5573',
#               'P1417',
#               'P4629',
#               'P1830',
#               'P948',
#               'P1740',
#               'P2884',
#               'P208',
#               'P2238',
#               'P1465',
#               'P2347',
#               'P85',
#               'P209',
#               'P2250',
#               'P1296',
#               'P361',
#               'P373',
#               'P78',
#               'P2046',
#               'P47',
#               'P6150',
#               'P31',
#               'P610',
#               'P1464',
#               'P2927',
#               'P4672',
#               'P1813',
#               'P1622',
#               'P2982',
#               'P1589',
#               'P3222',
#               'P898',
#               'P299',
#               'P421',
#               'P269',
#               'P5247',
#               'P150',
#               'P3024',
#               'P474',
#               'P646',
#               'P3175',
#               'P138',
#               'P244',
#               'P297',
#               'P1451',
#               'P163',
#               'P625',
#               'P901',
#               'P3509',
#               'P1343',
#               'P41',
#               'P5982',
#               'P5140',
#               'P92',
#               'P5019',
#               'P6104',
#               'P1842',
#               'P6573',
#               'P5250',
#               'P4801',
#               'P527',
#               'P1304',
#               'P2936',
#               'P6363',
#               'P6897',
#               'P5905',
#               'P3864',
#               'P6404',
#               'P1705',
#               'P7012',
#               'P6766',
#               'P5002',
#               'P6849',
#               'P989',
#               'P7471',
#               'P1245',
#               'P7314',
#               'P902',
#               'P3067',
#               'P2596',
#               'P5400',
#               'P7870',
#               'P7867',
#               'P2855',
#               'P7818',
#               'P7829',
#               'P7827',
#               'P7832',
#               'P7822',
#               'P443',
#               'P5437',
#               'P7982',
#               'P6058',
#               'P7859',
#               'P7322',
#               'P8349',
#               'P8402',
#               'P8408',
#               'P6385',
#               'P8406',
#               'P1365',
#               'P8519',
#               'P5063',
#               'P1438',
#               'P3749',
#               'P6200',
#               'P8714',
#               'P8744',
#               'P5587',
#               'P7157',
#               'P8826',
#               'P6839',
#               'P8309',
#               'P4527',
#               'P5456',
#               'P8974',
#               'P9037',
#               'P9100',
#               'P8814',
#               'P9123']})

# %% [markdown]
# # relation counting
# 각 entity마다 존재하는 relation을 확인하여 count하고 이를 rel_cnt_en, rel_cnt_ko 리스트에 저장한다.

# %%
from collections import Counter

def get_relation_count(entity_info_list):
    '''
    calculate relations frequency
    '''
    rel_info_list_en = []

    for info in entity_info_list:
        rel_info_list_en.extend(info['claims'])

    rel_cnt_en = Counter(rel_info_list_en)

    # sort by frequency of relation
    rel_cnt_en = sorted(rel_cnt_en.items(), key=lambda x: -x[1])
    
    # relation count is same for en and ko
    return rel_cnt_en, rel_cnt_en

# %%
# relation counting
rel_cnt_en, rel_cnt_ko = get_relation_count(ent_info_list_en)

# %%
rel_cnt_en
# Out:
# [('P31', 463154),
#  ('P646', 212974),
#  ('P17', 154666),
#  ('P18', 140776),
#  ('P373', 137764),
#  ('P2671', 125261),
#  ('P21', 122705),
#  ('P569', 118078),
#  ('P106', 116256),
#  ('P27', 110987),
#  ('P735', 108656),
#  ('P131', 103463),
#  ('P625', 102166),
#  ('P19', 102069),
#  ('P214', 98454),
#  ('P7859', 79596),
#  ('P570', 64513),
#  ('P734', 63378),
#  ('P244', 61894),
#  ('P227', 60438),
#  ('P171', 59680),
#  ('P225', 59676),
#  ('P105', 59676),
#  ('P213', 56070),
#  ('P846', 54904),
#  ('P1412', 51528),
#  ('P20', 50022),
#  ('P856', 48589),
#  ('P641', 48554),
#  ('P910', 45270),
#  ('P571', 43556),
#  ('P1566', 43023),
#  ('P5055', 42200),
#  ('P268', 36699),
#  ('P421', 35997),
#  ('P281', 34691),
#  ('P136', 32668),
#  ('P830', 32143),
#  ('P2044', 31949),
#  ('P2046', 31294),
#  ('P815', 29814),
#  ('P6766', 29603),
#  ('P269', 29444),
#  ('P345', 29311),
#  ('P1559', 29254),
#  ('P69', 28489),
#  ('P1082', 28454),
#  ('P577', 26128),
#  ('P1006', 25844),
#  ('P166', 25108),
#  ('P495', 24472),
#  ('P7902', 22659),
#  ('P3151', 22132),
#  ('P2163', 22099),
#  ('P1207', 21817),
#  ('P39', 21755),
#  ('P361', 21152),
#  ('P242', 21006),
#  ('P1343', 21005),
#  ('P1889', 20958),
#  ('P691', 20713),
#  ('P279', 20404),
#  ('P156', 20330),
#  ('P155', 20068),
#  ('P685', 17806),
#  ('P850', 17417),
#  ('P6366', 16710),
#  ('P1417', 16706),
#  ('P585', 15771),
#  ('P473', 15733),
#  ('P54', 15246),
#  ('P7293', 15173),
#  ('P463', 14707),
#  ('P102', 14136),
#  ('P47', 13756),
#  ('P2031', 13745),
#  ('P413', 13473),
#  ('P108', 13411),
#  ('P3417', 13301),
#  ('P1476', 13245),
#  ('P94', 13216),
#  ('P1344', 12721),
#  ('P937', 12710),
#  ('P1448', 12412),
#  ('P434', 12116),
#  ('P140', 12104),
#  ('P138', 11620),
#  ('P402', 11580),
#  ('P2048', 11567),
#  ('P159', 11521),
#  ('P407', 11262),
#  ('P648', 11005),
#  ('P2043', 10909),
#  ('P175', 10863),
#  ('P838', 10671),
#  ('P1871', 10626),
#  ('P264', 10614),
#  ('P364', 10414),
#  ('P276', 10378),
#  ('P2067', 10260),
#  ('P950', 10216),
#  ('P1953', 9876),
#  ('P2603', 9720),
#  ('P1435', 9672),
#  ('P119', 9523),
#  ('P7763', 9495),
#  ('P3430', 9406),
#  ('P7704', 9376),
#  ('P22', 9372),
#  ('P57', 9228),
#  ('P2002', 9127),
#  ('P935', 8849),
#  ('P3606', 8764),
#  ('P1296', 8688),
#  ('P161', 8561),
#  ('P360', 8560),
#  ('P26', 8541),
#  ('P1705', 8382),
#  ('P1843', 8370),
#  ('P40', 8282),
#  ('P2604', 8165),
#  ('P103', 8018),
#  ('P3138', 7735),
#  ('P86', 7499),
#  ('P6105', 7447),
#  ('P8687', 7429),
#  ('P527', 7407),
#  ('P627', 7332),
#  ('P141', 7331),
#  ('P162', 7311),
#  ('P1303', 7299),
#  ('P462', 7236),
#  ('P2605', 7220),
#  ('P6127', 7220),
#  ('P2529', 7106),
#  ('P1015', 7095),
#  ('P395', 6986),
#  ('P1532', 6972),
#  ('P2047', 6967),
#  ('P3373', 6962),
#  ('P3143', 6928),
#  ('P8286', 6805),
#  ('P36', 6765),
#  ('P2446', 6679),
#  ('P1313', 6636),
#  ('P576', 6626),
#  ('P127', 6525),
#  ('P607', 6453),
#  ('P6018', 6431),
#  ('P1447', 6421),
#  ('P580', 6375),
#  ('P58', 6356),
#  ('P436', 6335),
#  ('P2013', 6266),
#  ('P3987', 6219),
#  ('P3186', 6218),
#  ('P1266', 6208),
#  ('P509', 6155),
#  ('P2094', 6126),
#  ('P2019', 6086),
#  ('P6177', 6077),
#  ('P8034', 6036),
#  ('P137', 5996),
#  ('P750', 5964),
#  ('P1539', 5898),
#  ('P1619', 5898),
#  ('P1540', 5893),
#  ('P535', 5822),
#  ('P2949', 5763),
#  ('P349', 5719),
#  ('P1562', 5637),
#  ('P2924', 5569),
#  ('P2581', 5519),
#  ('P590', 5437),
#  ('P154', 5423),
#  ('P1477', 5398),
#  ('P582', 5381),
#  ('P2435', 5380),
#  ('P437', 5374),
#  ('P764', 5328),
#  ('P721', 5317),
#  ('P1315', 5280),
#  ('P949', 5250),
#  ('P4024', 5233),
#  ('P3288', 5164),
#  ('P1280', 5115),
#  ('P101', 5105),
#  ('P1616', 5026),
#  ('P1970', 5026),
#  ('P50', 5022),
#  ('P480', 5019),
#  ('P4807', 5008),
#  ('P1196', 4993),
#  ('P2348', 4986),
#  ('P1954', 4933),
#  ('P6375', 4917),
#  ('P1895', 4901),
#  ('P2639', 4788),
#  ('P2168', 4694),
#  ('P1376', 4638),
#  ('P25', 4617),
#  ('P41', 4612),
#  ('P1258', 4594),
#  ('P793', 4593),
#  ('P7938', 4579),
#  ('P1695', 4568),
#  ('P245', 4560),
#  ('P374', 4534),
#  ('P3762', 4515),
#  ('P1454', 4511),
#  ('P5032', 4505),
#  ('P906', 4437),
#  ('P5587', 4424),
#  ('P403', 4422),
#  ('P8422', 4421),
#  ('P3478', 4411),
#  ('P176', 4410),
#  ('P5573', 4386),
#  ('P1464', 4368),
#  ('P3240', 4344),
#  ('P650', 4337),
#  ('P344', 4286),
#  ('P840', 4275),
#  ('P118', 4211),
#  ('P1265', 4196),
#  ('P6671', 4184),
#  ('P61', 4181),
#  ('P5008', 4141),
#  ('P393', 4141),
#  ('P410', 4135),
#  ('P4342', 4131),
#  ('P2704', 4120),
#  ('P5019', 4112),
#  ('P575', 4037),
#  ('P5750', 4008),
#  ('P1939', 3940),
#  ('P8408', 3937),
#  ('P3219', 3934),
#  ('P2003', 3927),
#  ('P1346', 3875),
#  ('P4728', 3869),
#  ('P3450', 3867),
#  ('P961', 3790),
#  ('P2600', 3783),
#  ('P528', 3777),
#  ('P960', 3777),
#  ('P272', 3738),
#  ('P774', 3733),
#  ('P1741', 3724),
#  ('P5037', 3651),
#  ('P1017', 3638),
#  ('P7715', 3637),
#  ('P1263', 3609),
#  ('P3222', 3602),
#  ('P206', 3536),
#  ('P179', 3531),
#  ('P409', 3497),
#  ('P6886', 3489),
#  ('P53', 3456),
#  ('P664', 3442),
#  ('P1792', 3436),
#  ('P982', 3420),
#  ('P2020', 3419),
#  ('P905', 3411),
#  ('P1273', 3407),
#  ('P2638', 3399),
#  ('P1728', 3385),
#  ('P3107', 3384),
#  ('P2387', 3380),
#  ('P512', 3375),
#  ('P2752', 3366),
#  ('P2369', 3347),
#  ('P2574', 3293),
#  ('P842', 3292),
#  ('P241', 3263),
#  ('P4614', 3259),
#  ('P123', 3254),
#  ('P3031', 3251),
#  ('P3782', 3248),
#  ('P172', 3231),
#  ('P1077', 3218),
#  ('P149', 3191),
#  ('P150', 3182),
#  ('P6706', 3156),
#  ('P1281', 3149),
#  ('P1284', 3102),
#  ('P7959', 3098),
#  ('P1580', 3078),
#  ('P6864', 3062),
#  ('P6379', 3025),
#  ('P1005', 2999),
#  ('P5786', 2996),
#  ('P1132', 2988),
#  ('P3405', 2984),
#  ('P2631', 2978),
#  ('P4276', 2941),
#  ('P3043', 2920),
#  ('P97', 2902),
#  ('P6216', 2890),
#  ('P3302', 2889),
#  ('P197', 2883),
#  ('P1472', 2846),
#  ('P1457', 2836),
#  ('P460', 2825),
#  ('P81', 2812),
#  ('P551', 2810),
#  ('P5034', 2807),
#  ('P938', 2782),
#  ('P396', 2775),
#  ('P2346', 2763),
#  ('P921', 2760),
#  ('P708', 2749),
#  ('P9157', 2740),
#  ('P2843', 2733),
#  ('P170', 2727),
#  ('P716', 2706),
#  ('P2045', 2704),
#  ('P1096', 2699),
#  ('P2049', 2683),
#  ('P1040', 2669),
#  ('P5736', 2669),
#  ('P1667', 2668),
#  ('P196', 2667),
#  ('P3537', 2662),
#  ('P2248', 2661),
#  ('P490', 2657),
#  ('P2334', 2654),
#  ('P65', 2648),
#  ('P443', 2638),
#  ('P2325', 2637),
#  ('P2213', 2636),
#  ('P1269', 2627),
#  ('P1070', 2608),
#  ('P452', 2575),
#  ('P1442', 2568),
#  ('P3827', 2561),
#  ('P800', 2547),
#  ('P3844', 2539),
#  ('P1350', 2530),
#  ('P449', 2529),
#  ('P2326', 2501),
#  ('P948', 2495),
#  ('P4638', 2489),
#  ('P2146', 2460),
#  ('P6', 2455),
#  ('P1421', 2455),
#  ('P3630', 2453),
#  ('P2233', 2437),
#  ('P884', 2434),
#  ('P2243', 2424),
#  ('P2244', 2416),
#  ('P1711', 2415),
#  ('P4927', 2373),
#  ('P1874', 2367),
#  ('P4839', 2366),
#  ('P7818', 2363),
#  ('P5739', 2322),
#  ('P740', 2315),
#  ('P973', 2307),
#  ('P112', 2305),
#  ('P1814', 2283),
#  ('P271', 2277),
#  ('P2397', 2277),
#  ('P945', 2274),
#  ('P186', 2269),
#  ('P4552', 2266),
#  ('P706', 2254),
#  ('P3933', 2245),
#  ('P485', 2239),
#  ('P1754', 2231),
#  ('P6844', 2219),
#  ('P6257', 2217),
#  ('P6258', 2217),
#  ('P9037', 2212),
#  ('P6259', 2209),
#  ('P5731', 2208),
#  ('P59', 2199),
#  ('P3083', 2196),
#  ('P486', 2195),
#  ('P1366', 2187),
#  ('P2465', 2184),
#  ('P1819', 2154),
#  ('P1368', 2146),
#  ('P3212', 2139),
#  ('P3365', 2130),
#  ('P1415', 2126),
#  ('P84', 2123),
#  ('P1215', 2107),
#  ('P5263', 2088),
#  ('P1225', 2074),
#  ('P1047', 2074),
#  ('P4159', 2073),
#  ('P1001', 2073),
#  ('P190', 2071),
#  ('P1456', 2057),
#  ('P4947', 2057),
#  ('P135', 2047),
#  ('P4902', 2040),
#  ('P2427', 2036),
#  ('P7202', 2028),
#  ('P178', 2027),
#  ('P6782', 2018),
#  ('P2053', 2014),
#  ('P3500', 2011),
#  ('P8406', 1999),
#  ('P3726', 1988),
#  ('P1014', 1986),
#  ('P3120', 1986),
#  ('P9097', 1984),
#  ('P1411', 1975),
#  ('P1113', 1974),
#  ('P126', 1971),
#  ('P435', 1966),
#  ('P4212', 1961),
#  ('P1816', 1954),
#  ('P8971', 1949),
#  ('P1712', 1947),
#  ('P2626', 1940),
#  ('P2032', 1929),
#  ('P2519', 1927),
#  ('P7867', 1924),
#  ('P380', 1921),
#  ('P1469', 1921),
#  ('P1465', 1916),
#  ('P16', 1909),
#  ('P8033', 1905),
#  ('P782', 1893),
#  ('P15', 1891),
#  ('P2508', 1884),
#  ('P400', 1874),
#  ('P7224', 1871),
#  ('P7982', 1870),
#  ('P3065', 1868),
#  ('P2216', 1868),
#  ('P30', 1864),
#  ('P902', 1855),
#  ('P3171', 1832),
#  ('P1066', 1828),
#  ('P1986', 1818),
#  ('P1598', 1815),
#  ('P1365', 1814),
#  ('P1981', 1799),
#  ('P742', 1790),
#  ('P1813', 1781),
#  ('P1729', 1775),
#  ('P5534', 1769),
#  ('P4529', 1767),
#  ('P8750', 1765),
#  ('P5361', 1764),
#  ('P8707', 1764),
#  ('P1249', 1758),
#  ('P1441', 1755),
#  ('P4432', 1755),
#  ('P1977', 1751),
#  ('P2061', 1749),
#  ('P8851', 1745),
#  ('P6821', 1736),
#  ('P274', 1730),
#  ('P8814', 1718),
#  ('P6262', 1700),
#  ('P3129', 1699),
#  ('P8072', 1691),
#  ('P3896', 1688),
#  ('P4046', 1687),
#  ('P1552', 1685),
#  ('P366', 1681),
#  ('P109', 1671),
#  ('P1036', 1660),
#  ('P2888', 1655),
#  ('P5905', 1638),
#  ('P749', 1630),
#  ('P183', 1619),
#  ('P652', 1610),
#  ('P8915', 1599),
#  ('P508', 1577),
#  ('P3348', 1576),
#  ('P974', 1574),
#  ('P5504', 1569),
#  ('P968', 1567),
#  ('P7865', 1565),
#  ('P3593', 1565),
#  ('P8189', 1560),
#  ('P613', 1556),
#  ('P6275', 1551),
#  ('P3064', 1549),
#  ('P5033', 1545),
#  ('P7848', 1544),
#  ('P802', 1543),
#  ('P184', 1536),
#  ('P3088', 1531),
#  ('P611', 1527),
#  ('P6656', 1522),
#  ('P8974', 1521),
#  ('P8351', 1521),
#  ('P1103', 1520),
#  ('P144', 1512),
#  ('P4665', 1509),
#  ('P2464', 1502),
#  ('P2509', 1501),
#  ('P1992', 1485),
#  ('P2758', 1474),
#  ('P2755', 1473),
#  ('P2186', 1471),
#  ('P3203', 1461),
#  ('P1618', 1450),
#  ('P439', 1442),
#  ('P915', 1442),
#  ('P723', 1438),
#  ('P282', 1432),
#  ('P7937', 1429),
#  ('P5882', 1427),
#  ('P3804', 1416),
#  ('P7552', 1415),
#  ('P1549', 1414),
#  ('P8172', 1411),
#  ('P1969', 1401),
#  ('P3265', 1399),
#  ('P3973', 1399),
#  ('P3029', 1398),
#  ('P839', 1396),
#  ('P669', 1393),
#  ('P1933', 1391),
#  ('P2583', 1387),
#  ('P8094', 1386),
#  ('P4104', 1385),
#  ('P4208', 1381),
#  ('P1538', 1374),
#  ('P404', 1365),
#  ('P2437', 1364),
#  ('P651', 1363),
#  ('P7109', 1356),
#  ('P4823', 1353),
#  ('P998', 1346),
#  ('P4293', 1336),
#  ('P1233', 1336),
#  ('P185', 1334),
#  ('P1064', 1334),
#  ('P1424', 1330),
#  ('P5508', 1325),
#  ('P640', 1319),
#  ('P3616', 1318),
#  ('P7444', 1314),
#  ('P8988', 1313),
#  ('P2833', 1309),
#  ('P8849', 1307),
#  ('P231', 1305),
#  ('P6398', 1305),
#  ('P181', 1303),
#  ('P722', 1300),
#  ('P8947', 1297),
#  ('P1772', 1296),
#  ('P8980', 1295),
#  ('P3591', 1293),
#  ('P1157', 1284),
#  ('P1245', 1283),
#  ('P2936', 1265),
#  ('P2732', 1260),
#  ('P14', 1251),
#  ('P454', 1250),
#  ('P2347', 1249),
#  ('P825', 1249),
#  ('P1830', 1244),
#  ('P5138', 1241),
#  ('P1804', 1231),
#  ('P296', 1224),
#  ('P2040', 1214),
#  ('P1746', 1213),
#  ('P1220', 1204),
#  ('P676', 1202),
#  ('P1237', 1198),
#  ('P1045', 1198),
#  ('P2602', 1196),
#  ('P2481', 1192),
#  ('P1824', 1190),
#  ('P2426', 1182),
#  ('P235', 1180),
#  ('P2268', 1179),
#  ('P7929', 1177),
#  ('P488', 1177),
#  ('P4663', 1173),
#  ('P3444', 1172),
#  ('P1080', 1168),
#  ('P1409', 1167),
#  ('P662', 1166),
#  ('P234', 1166),
#  ('P223', 1164),
#  ('P1090', 1162),
#  ('P4527', 1159),
#  ('P4438', 1155),
#  ('P866', 1154),
#  ('P233', 1153),
#  ('P4095', 1152),
#  ('P8548', 1151),
#  ('P7335', 1150),
#  ('P37', 1148),
#  ('P661', 1142),
#  ('P5257', 1141),
#  ('P195', 1137),
#  ('P836', 1136),
#  ('P772', 1133),
#  ('P1651', 1128),
#  ('P3117', 1125),
#  ('P1971', 1112),
#  ('P2868', 1107),
#  ('P2276', 1103),
#  ('P1902', 1100),
#  ('P2205', 1094),
#  ('P4200', 1093),
#  ('P1146', 1093),
#  ('P115', 1090),
#  ('P5063', 1082),
#  ('P3961', 1074),
#  ('P1038', 1070),
#  ('P729', 1069),
#  ('P4081', 1067),
#  ('P1056', 1066),
#  ('P5383', 1064),
#  ('P1332', 1062),
#  ('P2342', 1060),
#  ('P1335', 1059),
#  ('P1334', 1059),
#  ('P3096', 1059),
#  ('P8494', 1059),
#  ('P1333', 1057),
#  ('P8047', 1055),
#  ('P180', 1046),
#  ('P8349', 1044),
#  ('P635', 1043),
#  ('P806', 1042),
#  ('P8179', 1027),
#  ('P6578', 1027),
#  ('P6404', 1026),
#  ('P647', 1025),
#  ('P6188', 1024),
#  ('P3615', 1023),
#  ('P5099', 1021),
#  ('P2416', 1021),
#  ('P3901', 1019),
#  ('P2503', 1014),
#  ('P358', 1012),
#  ('P3141', 1006),
#  ('P1663', 1006),
#  ('P2554', 999),
#  ('P243', 996),
#  ('P2036', 996),
#  ('P1545', 992),
#  ('P4223', 987),
#  ('P1083', 987),
#  ('P2518', 984),
#  ('P672', 983),
#  ('P8519', 982),
#  ('P2566', 980),
#  ('P232', 979),
#  ('P5607', 979),
#  ('P7842', 978),
#  ('P6832', 971),
#  ('P6925', 969),
#  ('P5749', 966),
#  ('P4835', 963),
#  ('P3241', 962),
#  ('P7084', 962),
#  ('P3501', 958),
#  ('P2963', 956),
#  ('P6194', 952),
#  ('P7699', 951),
#  ('P5473', 950),
#  ('P549', 949),
#  ('P239', 940),
#  ('P236', 940),
#  ('P6509', 939),
#  ('P3192', 937),
#  ('P3957', 936),
#  ('P1988', 935),
#  ('P5984', 929),
#  ('P3538', 922),
#  ('P2381', 917),
#  ('P2892', 914),
#  ('P2624', 914),
#  ('P4629', 912),
#  ('P4124', 912),
#  ('P1192', 911),
#  ('P291', 911),
#  ('P7033', 909),
#  ('P1128', 909),
#  ('P1375', 905),
#  ('P2026', 904),
#  ('P3208', 898),
#  ('P674', 893),
#  ('P843', 891),
#  ('P5247', 887),
#  ('P2588', 887),
#  ('P1801', 886),
#  ('P3427', 886),
#  ('P8296', 885),
#  ('P1320', 880),
#  ('P2042', 875),
#  ('P412', 874),
#  ('P7363', 873),
#  ('P683', 870),
#  ('P2927', 869),
#  ('P3963', 869),
#  ('P1285', 869),
#  ('P6722', 866),
#  ('P3639', 865),
#  ('P6885', 863),
#  ('P423', 863),
#  ('P3880', 860),
#  ('P8119', 858),
#  ('P1938', 857),
#  ('P466', 857),
#  ('P959', 856),
#  ('P6142', 856),
#  ('P1416', 854),
#  ('P5327', 852),
#  ('P1747', 852),
#  ('P4769', 852),
#  ('P3808', 846),
#  ('P3602', 845),
#  ('P2799', 845),
#  ('P3527', 844),
#  ('P1556', 840),
#  ('P3878', 839),
#  ('P8795', 836),
#  ('P4277', 836),
#  ('P7561', 830),
#  ('P4156', 830),
#  ('P2750', 820),
#  ('P8987', 818),
#  ('P814', 812),
#  ('P1142', 803),
#  ('P2383', 802),
#  ('P7214', 798),
#  ('P355', 796),
#  ('P2215', 795),
#  ('P2943', 793),
#  ('P9081', 792),
#  ('P3077', 789),
#  ('P8385', 784),
#  ('P2193', 782),
#  ('P3520', 782),
#  ('P4145', 776),
#  ('P8345', 775),
#  ('P411', 775),
#  ('P4459', 774),
#  ('P5491', 770),
#  ('P117', 769),
#  ('P237', 767),
#  ('P710', 765),
#  ('P3144', 763),
#  ('P5489', 760),
#  ('P1092', 759),
#  ('P4746', 758),
#  ('P2373', 751),
#  ('P3749', 750),
#  ('P7725', 750),
#  ('P4632', 750),
#  ('P566', 749),
#  ('P3879', 747),
#  ('P2601', 747),
#  ('P4282', 745),
#  ('P8998', 740),
#  ('P1449', 739),
#  ('P3135', 734),
#  ('P5331', 732),
#  ('P4457', 729),
#  ('P163', 726),
#  ('P1937', 726),
#  ('P238', 726),
#  ('P1866', 726),
#  ('P275', 725),
#  ('P8317', 725),
#  ('P592', 723),
#  ('P931', 719),
#  ('P1394', 713),
#  ('P747', 712),
#  ('P1427', 710),
#  ('P4613', 709),
#  ('P2747', 706),
#  ('P5357', 705),
#  ('P7578', 704),
#  ('P3965', 703),
#  ('P3182', 701),
#  ('P5400', 697),
#  ('P1051', 697),
#  ('P4985', 693),
#  ('P7886', 692),
#  ('P3154', 691),
#  ('P5970', 689),
#  ('P6839', 687),
#  ('P665', 685),
#  ('P3542', 684),
#  ('P1081', 683),
#  ('P1950', 677),
#  ('P3118', 676),
#  ('P809', 673),
#  ('P8714', 672),
#  ('P3371', 672),
#  ('P5909', 670),
#  ('P630', 667),
#  ('P2174', 667),
#  ('P2257', 664),
#  ('P5597', 662),
#  ('P5794', 662),
#  ('P1585', 660),
#  ('P6555', 660),
#  ('P5036', 658),
#  ('P215', 656),
#  ('P2124', 654),
#  ('P3569', 652),
#  ('P300', 650),
#  ('P2447', 650),
#  ('P289', 650),
#  ('P6351', 649),
#  ('P1367', 649),
#  ('P559', 649),
#  ('P451', 647),
#  ('P3990', 647),
#  ('P7194', 646),
#  ('P6562', 644),
#  ('P9049', 642),
#  ('P841', 638),
#  ('P1936', 637),
#  ('P3876', 635),
#  ('P4790', 635),
#  ('P1341', 634),
#  ('P3280', 633),
#  ('P8989', 633),
#  ('P287', 632),
#  ('P8234', 631),
#  ('P954', 629),
#  ('P8826', 627),
#  ('P989', 626),
#  ('P286', 624),
#  ('P2214', 624),
#  ('P3598', 621),
#  ('P305', 618),
#  ('P3696', 618),
#  ('P1274', 617),
#  ('P3018', 615),
#  ('P2261', 614),
#  ('P9160', 607),
#  ('P3999', 607),
#  ('P212', 607),
#  ('P4969', 606),
#  ('P220', 603),
#  ('P1191', 602),
#  ('P1853', 600),
#  ('P479', 600),
#  ('P8383', 600),
#  ('P2632', 600),
#  ('P371', 600),
#  ('P6264', 599),
#  ('P2722', 594),
#  ('P5698', 592),
#  ('P2341', 591),
#  ('P397', 590),
#  ('P348', 589),
#  ('P2788', 589),
#  ('P1185', 587),
#  ('P4391', 587),
#  ('P8440', 584),
#  ('P858', 584),
#  ('P737', 582),
#  ('P158', 582),
#  ('P5375', 581),
#  ('P4983', 581),
#  ('P1644', 580),
#  ('P6228', 579),
#  ('P1716', 579),
#  ('P205', 577),
#  ('P865', 577),
#  ('P3157', 577),
#  ('P6412', 576),
#  ('P4955', 575),
#  ('P6544', 575),
#  ('P6546', 574),
#  ('P6545', 574),
#  ('P4619', 572),
#  ('P2850', 572),
#  ('P7807', 571),
#  ('P3305', 570),
#  ('P2252', 570),
#  ('P2191', 568),
#  ('P9164', 566),
#  ('P2001', 564),
#  ('P1727', 564),
#  ('P2635', 563),
#  ('P4515', 559),
#  ('P2660', 557),
#  ('P3056', 556),
#  ('P609', 556),
#  ('P6783', 556),
#  ('P359', 555),
#  ('P428', 554),
#  ('P586', 554),
#  ('P1140', 552),
#  ('P768', 552),
#  ('P6058', 551),
#  ('P2515', 549),
#  ('P1050', 547),
#  ('P1627', 547),
#  ('P5338', 546),
#  ('P516', 545),
#  ('P1995', 545),
#  ('P2262', 545),
#  ('P2685', 544),
#  ('P7970', 543),
#  ('P1745', 543),
#  ('P3051', 541),
#  ('P3660', 540),
#  ('P2969', 539),
#  ('P7049', 538),
#  ('P3823', 538),
#  ('P3133', 538),
#  ('P5395', 535),
#  ('P3225', 535),
#  ('P5815', 534),
#  ('P951', 534),
#  ('P3145', 533),
#  ('P1329', 533),
#  ('P1317', 533),
#  ('P5456', 532),
#  ('P2506', 532),
#  ('P1942', 531),
#  ('P177', 531),
#  ('P461', 530),
#  ('P579', 529),
#  ('P8181', 528),
#  ('P277', 527),
#  ('P306', 527),
#  ('P1071', 525),
#  ('P217', 521),
#  ('P6543', 521),
#  ('P6547', 521),
#  ('P1391', 520),
#  ('P3413', 519),
#  ('P712', 519),
#  ('P962', 518),
#  ('P4491', 516),
#  ('P4780', 515),
#  ('P4332', 514),
#  ('P713', 513),
#  ('P1248', 511),
#  ('P2283', 511),
#  ('P8496', 511),
#  ('P2703', 510),
#  ('P2789', 509),
#  ('P957', 509),
#  ('P724', 508),
#  ('P417', 506),
#  ('P6145', 506),
#  ('P2977', 505),
#  ('P946', 505),
#  ('P1037', 504),
#  ('P1802', 503),
#  ('P901', 502),
#  ('P4553', 500),
#  ('P1579', 500),
#  ('P465', 500),
#  ('P1004', 500),
#  ('P7944', 499),
#  ('P6340', 499),
#  ('P7749', 498),
#  ('P2354', 496),
#  ('P3935', 494),
#  ('P3594', 492),
#  ('P711', 491),
#  ('P9179', 489),
#  ('P1612', 489),
#  ('P3872', 489),
#  ('P3925', 488),
#  ('P6047', 488),
#  ('P1422', 487),
#  ('P953', 485),
#  ('P5035', 483),
#  ('P5570', 482),
#  ('P8235', 482),
#  ('P6507', 481),
#  ('P2959', 479),
#  ('P6827', 479),
#  ('P1267', 479),
#  ('P8021', 477),
#  ('P3655', 475),
#  ('P427', 475),
#  ('P1808', 474),
#  ('P1899', 473),
#  ('P2971', 473),
#  ('P4933', 473),
#  ('P8432', 471),
#  ('P7711', 470),
#  ('P7117', 468),
#  ('P3153', 467),
#  ('P6181', 466),
#  ('P1399', 464),
#  ('P6814', 464),
#  ('P1997', 462),
#  ('P1877', 461),
#  ('P1791', 460),
#  ('P4789', 460),
#  ('P1403', 458),
#  ...]

# %%
df = pd.DataFrame(rel_cnt_en, columns=['relation id', 'count'])
df.T
# Out:
#                0       1       2       3       4       5       6       7     \
# relation id     P31    P646     P17     P18    P373   P2671     P21    P569
# count        463154  212974  154666  140776  137764  125261  122705  118078
#
#                8       9     ...   6529   6530   6531   6532   6533   6534  \
# relation id    P106     P27  ...  P4051  P2490  P3821  P6062  P6420  P8373
# count        116256  110987  ...      1      1      1      1      1      1
#
#               6535   6536   6537   6538
# relation id  P8377  P6101  P3996  P5436
# count            1      1      1      1
#
# [2 rows x 6539 columns]

# %%
df.head(20)
# Out:
#    relation id   count
# 0          P31  463154
# 1         P646  212974
# 2          P17  154666
# 3          P18  140776
# 4         P373  137764
# 5        P2671  125261
# 6          P21  122705
# 7         P569  118078
# 8         P106  116256
# 9          P27  110987
# 10        P735  108656
# 11        P131  103463
# 12        P625  102166
# 13         P19  102069
# 14        P214   98454
# 15       P7859   79596
# 16        P570   64513
# 17        P734   63378
# 18        P244   61894
# 19        P227   60438

# %% [markdown]
# entity 499994개에 대해 조사했을 때 relation의 종류는 6539가지.

# %% [markdown]
# | P31 | P646 | P17 | P18 | P373 | P2671 | P21 | P569 | P106 | P27 |
# |:--- |:----:|:---:|:---:|:----:|:-----:|:---:|:----:|:----:|----:|
# |instance of| Freebase ID | country | image | Commons category | Google Knowledge Graph ID | sex or gender | date of birth | occupation | country of citizenship |
# |다음 종류에 속함 | Freebase 식별자 | 다음 나라의 것임 | 모습 | 이 주제를 다루는 공용 분류 | 구글 지식 그래프 ID | 성별 | 태어난 날 | 직업 | 국적 |

# %%
entities[0]['claims']['P373']
# Out:
# [{'mainsnak': {'snaktype': 'value',
#    'property': 'P373',
#    'datavalue': {'value': 'Belgium', 'type': 'string'},
#    'datatype': 'string'},
#   'type': 'statement',
#   'id': 'q31$912C9A63-F124-4F42-8C0C-8A3E5AC8833B',
#   'rank': 'normal'}]

# %%
ent_info_list_en[1]['labels']
# Out:
# 'happiness'

# %%
entities[1]['claims']['P373']
# Out:
# [{'mainsnak': {'snaktype': 'value',
#    'property': 'P373',
#    'datavalue': {'value': 'Happiness', 'type': 'string'},
#    'datatype': 'string'},
#   'type': 'statement',
#   'id': 'q8$0FC7FB9A-B5CA-4762-98AE-1B0BDC1EEF39',
#   'rank': 'normal'}]

# %% [markdown]
# # 남은 works
# - 각 relation id에 대해 labels로 치환하는 문제 - api?
# - 특정 domain의 free text에서 relation extraction을 한다고 할 때 필요있을 relation과 필요없을 relation 구분?
